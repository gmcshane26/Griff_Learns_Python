# %%
#Using Dictionaries in Python 
Dict1={"Mookies":1, "The Bodyguard":1992}
Dict1["The Bodyguard"]
# Out:
# 1992

# %%
del(Dict1["Mookies"])

# %%
print(Dict1)
# Out:
# {'The Bodyguard': 1992}

# %%
"The Bodyguard" in Dict1
# Out:
# True
